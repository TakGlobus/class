# %%
import os
import copy
import math
import glob
import numpy as np
import imageio
import matplotlib.pyplot as plt
from matplotlib import patches as mpl_patches

# %%
def img_preprocess(filedir=''):
    im = imageio.imread(filedir)
    gray_scale = im.mean(axis=2)
    return gray_scale

# %%
test_img = imageio.imread("./class.jpg")

# %%
plt.imshow(test_img)

# %%
def gen_patches(img, stride=64, patch_size=128):
    windows = []
    nx, ny = img.shape
    for i in range(0, nx, stride):
        for j in range(0, ny, stride):
            if i + patch_size <= img.shape[0] and j + patch_size <= img.shape[1]:
                windows +=[img[i:i + patch_size, j:j + patch_size].astype(float)]
    return np.asarray(windows)

# %%
patches = gen_patches(test_img)

# %%
patches.shape
# Out:
# (120, 128, 128)

# %%
patches.shape
# Out:
# (456, 128, 128)

# %% [markdown]
# ### Stride = 128

# %%
plt.imshow(patches[40])

# %%
plt.imshow(patches[41])

# %%
plt.imshow(patches[42])

# %% [markdown]
# #### Stride = 64

# %%
plt.imshow(patches[100])

# %%
plt.imshow(patches[101])
